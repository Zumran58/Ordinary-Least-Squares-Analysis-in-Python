# %% [markdown]
# # Welcome to Jupyter!

# %%
#pip install -U scikit-learn scipy matplotlib

# %%
#pip install scikit-learn

# %%
import _pickle as pickle

import pandas as pd
import numpy as np

from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# %% [markdown]
# # Fitting and Diagnostics
#
# Some fitting techniques used were the OLS, LASSO, Ridge Regression and Elastic Net Regression.
#
# For ordinary least squares, some advantages include it is relatively fast and easy to compute, it is applicable in most machine learning problems. It can effective if its assumptions are met(that is little to no outliers and linearity in data).
# For OLS, disadvantages include poor performance in the presence of outliers and so the weights may have to reduced for outliers in order to retain performance. It also performs poorly on non-linear datasets, becuase OLS assumes linearlity in data. It also had a strong tendency to overfit data, especially when the degree of the polynomial is too high. Lasso and Ridge regression will be a better choice in higher dimensional situtations since they are designed to avoid overfitting.
#
# For Lasso, some advantages include the fact that it selects features through the process of feature selection and regularization od data models, thereby shrinking the coefficient to 0. Regularization basically consists of adding a penalty to the different parameters of the machine learning model to reduce the freedom of the model. Lasso tries to minimize the cost of regression, by choosing only those features that are useful and discarding redundant ones. As a result, it also tends to avoid overfitting.
#
# Some disadvantages incude the fact that selected features will be highly biased, and that prediction performance can be worse than Ridge Regression. Additonally if the dimension p is large to the extent that n<<p for n features, LASSO can select at most n features. After this point, the model will saturate, which is the state that the neuron predominantly outputs values close to the asymptotic ends of the bounded activation function.
#
# Interestingly, Lasso can be applied even when the number of features is larger than the number of data points.
#
# Smilarly for Ridge regession, it avoid overfitting of the model through feature selection and regularization, but it does not have the problem of selecting more than n predictors when n<<p, whereas LASSO saturates when n<<p.
#
# Disadvatanges of Ridge: It includes all the predictors in the final model, is unable to perform feature selection and it trades variance for bias.
#
# For Elastic net regression,it doesn’t have the problem of selecting more than n predictors when n<<p, whereas LASSO saturates when n<<p. It essentially takes the convex combination of Lasso and Ridge to get the benefits of both models
#
# However, it is computationally much more expensive than both LASSO and Ridge and should only be used for higher dimensional models.

# %%
TESTRANGE=83

ALPHA=0.001

trackers=[]

def OLS_Regression(train_X, train_Y, test_X, test_Y):
    
    reg=LinearRegression()
    
    reg.fit(train_X, train_Y)
    
    y_pred=reg.predict(test_X)
    
    
    for i in range(45):
        
        plt.scatter(test_X, [y for y in test_Y], color="black")
        
        plt.plot(test_X,  [y for y in y_pred], color="blue", linewidth=3)
        
        plt.xlabel("Time ")
        
        plt.ylabel("EMV value")
        
        plt.title(OLS REgession)
        
        plt.show()

# %%
with open(r'/home/jovyan/binder/MEMV.csv', "rb") as f:

    
    df=pd.read_csv(r'/home/jovyan/binder/MEMV.csv')
    df

# %%
df
# Out:
#         Date      EMV  Political Uncertainty Tracker  \
# 0    1990-01  17.8882                         7.9697
# 1    1990-02  22.1500                         9.6857
# 2    1990-03  17.6410                         8.7400
# 3    1990-04  15.9283                         6.8080
# 4    1990-05  12.1001                         6.0545
# ..       ...      ...                            ...
# 377  2021-06  21.9521                        10.0916
# 378  2021-07  16.6235                         7.2485
# 379  2021-08  19.6411                         9.0514
# 380  2021-09  23.4802                        12.5473
# 381  2021-10  19.0222                         9.3300
#
#      Infectious Disease EMV Tracker  \
# 0                            0.2411
# 1                            0.7699
# 2                            0.2673
# 3                            0.1493
# 4                            0.2521
# ..                              ...
# 377                         12.5927
# ...

# %%
y=df["EMV"]

a_list = list(range(0, 382))
  
x=np.array(a_list)

# %%
train_X, test_X, train_Y, test_Y = train_test_split(x.reshape(-1,1),y)

# %%
test_Y
# Out:
# 216    34.5524
# 368    20.9300
# 101    24.2027
# 41     14.8227
# 224    55.9658
#         ...
# 220    18.9287
# 195    14.3594
# 138    22.3187
# 176    14.3007
# 32     14.7631
# Name: EMV, Length: 96, dtype: float64

# %%
OLS_Regression(train_X, train_Y, test_X, test_Y)

# %%
def Lasso_Regression(train_X, train_Y, test_X, test_Y):
    
    reg=Lasso(alpha=ALPHA)
    
    reg.fit(train_X, train_Y)
    
    y_pred=reg.predict(test_X)
    
    
    for i in range(45):
        
        plt.scatter(test_X, [y for y in test_Y], color="black")
        
        plt.plot(test_X,  [y for y in y_pred], color="blue", linewidth=3)
        
        plt.xlabel("Time ")
        
        plt.ylabel("EMV value")
        
        plt.title("Lasso REgession - ")
        
        plt.show()

# %%
Lasso_Regression(train_X, train_Y, test_X, test_Y)

# %%
ALPHA=0.001
def Ridge_reg(train_X,train_Y,test_X,test_Y):
    
    reg=Ridge(alpha=0.001)
    
    reg.fit(train_X, train_Y)
    
    y_pred=reg.predict(test_X)
    
    
    for i in range(45):
        
        plt.scatter(test_X, [y for y in test_Y], color="black")
        
        plt.plot(test_X,  [y for y in y_pred], color="blue", linewidth=3)
        
        plt.xlabel("Time ")
        
        plt.ylabel("EMV value")
        
        plt.title("Ridge REgession ")
        
        plt.show()

# %%
Ridge_reg(train_X, train_Y, test_X, test_Y)

# %%
def Elastic_Reg(train_X, train_Y, test_X, test_Y):
    
    reg=ElasticNet(alpha=ALPHA)
    
    reg.fit(train_X, train_Y)
    
    y_pred=reg.predict(test_X)
    
    
    for i in range(45):
        
        plt.scatter(test_X, [y for y in test_Y], color="black")
        
        plt.plot(test_X,  [y for y in y_pred], color="blue", linewidth=3)
        
        plt.xlabel("Time ")
        
        plt.ylabel("EMV value")
        
        plt.title("Elastic Regession")
        
        plt.show()

# %%
Elastic_Reg(train_X, train_Y, test_X, test_Y)
